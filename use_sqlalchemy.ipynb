# %% [markdown]
# SQL Alchemyを使ってみる練習

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
engine = create_engine('mysql+pymysql://uma:UmaUma123!@localhost/everydb2?charset=utf8')
Base = automap_base()
Base.prepare(engine, reflect=True)
session = Session(engine)
N_UMA_RACE = Base.classes.N_UMA_RACE
N_RACE = Base.classes.N_RACE

# %%
year = 2016
query1 = session.query(N_RACE).filter(N_RACE.Year == year)
query2 = session.query(
    N_UMA_RACE.Year,
    N_UMA_RACE.MonthDay,
    N_UMA_RACE.JyoCD,
    N_UMA_RACE.RaceNum,
    N_UMA_RACE.Bamei,
    N_UMA_RACE.Umaban,
    ).filter(N_UMA_RACE.Year == year)
df = pd.read_sql(query2.statement, query2.session.bind)
df
# Out:
#        Year MonthDay JyoCD RaceNum               Bamei Umaban
# 0      2016     0409    03      01            シンボリメルケル     15
# 1      2016     0409    03      01                ゼラルダ     10
# 2      2016     0409    03      01              モズエエヤン     03
# 3      2016     0409    03      01           ジョリガーニャント     11
# 4      2016     0409    03      01             クラウンロマン     13
# 5      2016     0409    03      01                サノルア     12
# 6      2016     0409    03      01              ローズオーラ     08
# 7      2016     0409    03      01            ピントゥリッキオ     14
# 8      2016     0409    03      01           ローマンカモミール     04
# 9      2016     0409    03      01               スクラッタ     05
# 10     2016     0409    03      01            ルーセントアイズ     09
# 11     2016     0409    03      01             ディスグラース     06
# 12     2016     0409    03      01             アイヅナヨタケ     01
# 13     2016     0409    03      01              レディーゴー     02
# ...
